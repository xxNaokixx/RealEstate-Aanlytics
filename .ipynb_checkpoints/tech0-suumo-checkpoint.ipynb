# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [155], in <cell line: 5>()
#       3 from matplotlib import pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 5 from sklearn.linear_model import LinearRegression as LR
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (3.6.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.19 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: six>=1.5 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_excel("SUUMOスクレイピング.xlsx")

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
data.head()
# Out:
#           名称    カテゴリー         アドレス            アクセス   築年数   構造  階数      家賃  \
# 0  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/千歳烏山駅 歩11分  築27年  3階建  1階  13.8万円
# 1  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/芦花公園駅 歩20分  築27年  3階建  1階  13.8万円
# 2  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６    京王線/仙川駅 歩23分  築27年  3階建  1階  13.8万円
# 3   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４  小田急線/千歳船橋駅 歩6分   築3年  3階建  2階    18万円
# 4   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４   小田急線/経堂駅 歩12分   築3年  3階建  2階    18万円
#
#      管理費      敷金    礼金   間取り       面積  \
# 0      -  13.8万円     -  3LDK  65.72m2
# 1      -  13.8万円     -  3LDK  65.72m2
# 2      -  13.8万円     -  3LDK  65.72m2
# 3  5000円       -  36万円  2LDK   56.5m2
# 4  5000円       -  36万円  2LDK   56.5m2
#
#                                                  URL
# 0  https://suumo.jp/chintai/jnc_000077135145/?bc=...
# 1  https://suumo.jp/chintai/jnc_000077135145/?bc=...
# 2  https://suumo.jp/chintai/jnc_000077135145/?bc=...
# 3  https://suumo.jp/chintai/jnc_000076182006/?bc=...
# 4  https://suumo.jp/chintai/jnc_000076182006/?bc=...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144624 entries, 0 to 144623
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   名称      144624 non-null  object
#  1   カテゴリー   144624 non-null  object
#  2   アドレス    144624 non-null  object
#  3   アクセス    144624 non-null  object
#  4   築年数     144624 non-null  object
#  5   構造      144624 non-null  object
#  6   階数      144624 non-null  object
#  7   家賃      144624 non-null  object
#  8   管理費     144624 non-null  object
#  9   敷金      144624 non-null  object
#  10  礼金      144624 non-null  object
#  11  間取り     144624 non-null  object
#  12  面積      144624 non-null  object
#  13  URL     144624 non-null  object
# dtypes: object(14)
# memory usage: 15.4+ MB

# %%
#データの整形

# %%
#徒歩を別セルに分割
data["徒歩分"] = data["アクセス"].apply(lambda x : x.split(" ")[1])
data["徒歩"] = data["徒歩分"].apply(lambda x : x.split('分')[0])
data["walk"] = data["徒歩"].apply(lambda x : x.split('歩')[1])
data.head()
# Out:
#           名称    カテゴリー         アドレス            アクセス   築年数   構造  階数      家賃  \
# 0  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/千歳烏山駅 歩11分  築27年  3階建  1階  13.8万円
# 1  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/芦花公園駅 歩20分  築27年  3階建  1階  13.8万円
# 2  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６    京王線/仙川駅 歩23分  築27年  3階建  1階  13.8万円
# 3   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４  小田急線/千歳船橋駅 歩6分   築3年  3階建  2階    18万円
# 4   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４   小田急線/経堂駅 歩12分   築3年  3階建  2階    18万円
#
#      管理費      敷金    礼金   間取り       面積  \
# 0      -  13.8万円     -  3LDK  65.72m2
# 1      -  13.8万円     -  3LDK  65.72m2
# 2      -  13.8万円     -  3LDK  65.72m2
# 3  5000円       -  36万円  2LDK   56.5m2
# 4  5000円       -  36万円  2LDK   56.5m2
#
#                                                  URL   徒歩分   徒歩 walk
# 0  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩11分  歩11   11
# 1  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩20分  歩20   20
# 2  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩23分  歩23   23
# 3  https://suumo.jp/chintai/jnc_000076182006/?bc=...   歩6分   歩6    6
# 4  https://suumo.jp/chintai/jnc_000076182006/?bc=...  歩12分  歩12   12

# %%
#数字型で保管
data["walk"] = data["walk"].astype(np.int)
data.info()
# Out:
# /var/folders/9j/g3nm72s54g5df75_4gzcrxth0000gn/T/ipykernel_42739/27690869.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data["walk"] = data["walk"].astype(np.int)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144624 entries, 0 to 144623
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   名称      144624 non-null  object
#  1   カテゴリー   144624 non-null  object
#  2   アドレス    144624 non-null  object
#  3   アクセス    144624 non-null  object
#  4   築年数     144624 non-null  object
#  5   構造      144624 non-null  object
#  6   階数      144624 non-null  object
#  7   家賃      144624 non-null  object
#  8   管理費     144624 non-null  object
#  9   敷金      144624 non-null  object
#  10  礼金      144624 non-null  object
#  11  間取り     144624 non-null  object
#  12  面積      144624 non-null  object
#  13  URL     144624 non-null  object
#  14  徒歩分     144624 non-null  object
#  15  徒歩      144624 non-null  object
#  16  walk    144624 non-null  int64
# dtypes: int64(1), object(16)
# memory usage: 18.8+ MB

# %%
#家賃を別セルに分割
data["家賃金額"] = data["家賃"].apply(lambda x : x.split("万円")[0])
data.head()
# Out:
#           名称    カテゴリー         アドレス            アクセス   築年数   構造  階数      家賃  \
# 0  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/千歳烏山駅 歩11分  築27年  3階建  1階  13.8万円
# 1  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/芦花公園駅 歩20分  築27年  3階建  1階  13.8万円
# 2  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６    京王線/仙川駅 歩23分  築27年  3階建  1階  13.8万円
# 3   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４  小田急線/千歳船橋駅 歩6分   築3年  3階建  2階    18万円
# 4   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４   小田急線/経堂駅 歩12分   築3年  3階建  2階    18万円
#
#      管理費      敷金    礼金   間取り       面積  \
# 0      -  13.8万円     -  3LDK  65.72m2
# 1      -  13.8万円     -  3LDK  65.72m2
# 2      -  13.8万円     -  3LDK  65.72m2
# 3  5000円       -  36万円  2LDK   56.5m2
# 4  5000円       -  36万円  2LDK   56.5m2
#
#                                                  URL   徒歩分   徒歩  walk  家賃金額
# 0  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩11分  歩11    11  13.8
# 1  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩20分  歩20    20  13.8
# 2  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩23分  歩23    23  13.8
# 3  https://suumo.jp/chintai/jnc_000076182006/?bc=...   歩6分   歩6     6    18
# 4  https://suumo.jp/chintai/jnc_000076182006/?bc=...  歩12分  歩12    12    18

# %%
#数字型で保管

# %%
#平米を別セルに分割
data["平米数"] = data["面積"].apply(lambda x : x.split("m2")[0])
data.head()
# Out:
#           名称    カテゴリー         アドレス            アクセス   築年数   構造  階数      家賃  \
# 0  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/千歳烏山駅 歩11分  築27年  3階建  1階  13.8万円
# 1  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/芦花公園駅 歩20分  築27年  3階建  1階  13.8万円
# 2  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６    京王線/仙川駅 歩23分  築27年  3階建  1階  13.8万円
# 3   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４  小田急線/千歳船橋駅 歩6分   築3年  3階建  2階    18万円
# 4   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４   小田急線/経堂駅 歩12分   築3年  3階建  2階    18万円
#
#      管理費      敷金    礼金   間取り       面積  \
# 0      -  13.8万円     -  3LDK  65.72m2
# 1      -  13.8万円     -  3LDK  65.72m2
# 2      -  13.8万円     -  3LDK  65.72m2
# 3  5000円       -  36万円  2LDK   56.5m2
# 4  5000円       -  36万円  2LDK   56.5m2
#
#                                                  URL   徒歩分   徒歩  walk  家賃金額  \
# 0  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩11分  歩11    11  13.8
# 1  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩20分  歩20    20  13.8
# 2  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩23分  歩23    23  13.8
# 3  https://suumo.jp/chintai/jnc_000076182006/?bc=...   歩6分   歩6     6    18
# 4  https://suumo.jp/chintai/jnc_000076182006/?bc=...  歩12分  歩12    12    18
#
#      平米数
# 0  65.72
# 1  65.72
# 2  65.72
# 3   56.5
# 4   56.5

# %%
#数字型で保管

# %%
#築年数を別セルに分割
data["築年数test"] = data["築年数"].apply(lambda x : x.split("年")[0])
data["築年数数字"] = data["築年数test"].apply(lambda x : x.split("築")[1])
data.head()
# Out:
#           名称    カテゴリー         アドレス            アクセス   築年数   構造  階数      家賃  \
# 0  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/千歳烏山駅 歩11分  築27年  3階建  1階  13.8万円
# 1  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/芦花公園駅 歩20分  築27年  3階建  1階  13.8万円
# 2  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６    京王線/仙川駅 歩23分  築27年  3階建  1階  13.8万円
# 3   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４  小田急線/千歳船橋駅 歩6分   築3年  3階建  2階    18万円
# 4   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４   小田急線/経堂駅 歩12分   築3年  3階建  2階    18万円
#
#      管理費      敷金  ...   間取り       面積  \
# 0      -  13.8万円  ...  3LDK  65.72m2
# 1      -  13.8万円  ...  3LDK  65.72m2
# 2      -  13.8万円  ...  3LDK  65.72m2
# 3  5000円       -  ...  2LDK   56.5m2
# 4  5000円       -  ...  2LDK   56.5m2
#
#                                                  URL   徒歩分   徒歩 walk  家賃金額  \
# 0  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩11分  歩11   11  13.8
# 1  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩20分  歩20   20  13.8
# 2  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩23分  歩23   23  13.8
# 3  https://suumo.jp/chintai/jnc_000076182006/?bc=...   歩6分   歩6    6    18
# 4  https://suumo.jp/chintai/jnc_000076182006/?bc=...  歩12分  歩12   12    18
#
#      平米数 築年数test 築年数数字
# 0  65.72     築27    27
# 1  65.72     築27    27
# 2  65.72     築27    27
# 3   56.5      築3     3
# 4   56.5      築3     3
#
# [5 rows x 21 columns]

# %%
#新築を0に変換

# %%
#数字型で保管

# %%
#いらない列を削除 
data['walk'] = data['walk'].astype('int')
data["平米数"] = data["平米数"].astype('float')
print(data.dtypes)
# Out:
# 名称          object
# カテゴリー       object
# アドレス        object
# アクセス        object
# 築年数         object
# 構造          object
# 階数          object
# 家賃          object
# 管理費         object
# 敷金          object
# 礼金          object
# 間取り         object
# 面積          object
# URL         object
# 徒歩分         object
# 徒歩          object
# walk         int64
# 家賃金額        object
# 平米数        float64
# 築年数test     object
# 築年数数字       object
# dtype: object

# %%
##新築を〇に変換
replace = data["築年数数字"].replace("新築", 0)
data_updated = data.replace("新築", "0")
data_updated2 = data.replace("", "0")

# %%
data["築年数数字"].describe()
# Out:
# count     144624
# unique        19
# top            2
# freq       34584
# Name: 築年数数字, dtype: object

# %%
replace.describe()
# Out:
# count     144624
# unique        19
# top            2
# freq       34584
# Name: 築年数数字, dtype: object

# %%
replace.head()
# Out:
# 0    27
# 1    27
# 2    27
# 3     3
# 4     3
# Name: 築年数数字, dtype: object

# %%
data_updated["築年数数字"].describe()
# Out:
# count     144624
# unique        19
# top            2
# freq       34584
# Name: 築年数数字, dtype: object

# %%
data_updated.head(195)
# Out:
#                          名称         カテゴリー         アドレス               アクセス  \
# 0                 シンセリティ北烏山       賃貸マンション  東京都世田谷区北烏山６     京王線/千歳烏山駅 歩11分
# 1                 シンセリティ北烏山       賃貸マンション  東京都世田谷区北烏山６     京王線/芦花公園駅 歩20分
# 2                 シンセリティ北烏山       賃貸マンション  東京都世田谷区北烏山６       京王線/仙川駅 歩23分
# 3                  サントーレア経堂        賃貸アパート   東京都世田谷区経堂４     小田急線/千歳船橋駅 歩6分
# 4                  サントーレア経堂        賃貸アパート   東京都世田谷区経堂４      小田急線/経堂駅 歩12分
# ..                      ...           ...          ...                ...
# 190  瀬田の杜　Garden＆Terrace　B棟  賃貸テラス・タウンハウス   東京都世田谷区瀬田２  東急大井町線/二子玉川駅 歩10分
# 191  瀬田の杜　Garden＆Terrace　B棟  賃貸テラス・タウンハウス   東京都世田谷区瀬田２   東急大井町線/上野毛駅 歩16分
# 192                   ヴィエント        賃貸アパート   東京都世田谷区経堂３       小田急線/経堂駅 歩7分
# 193                   ヴィエント        賃貸アパート   東京都世田谷区経堂３       小田急線/経堂駅 歩7分
# 194                   ヴィエント        賃貸アパート   東京都世田谷区経堂３       小田急線/経堂駅 歩7分
#
#       築年数   構造    階数      家賃    管理費      敷金  ...   間取り        面積  \
# 0    築27年  3階建    1階  13.8万円      -  13.8万円  ...  3LDK   65.72m2
# 1    築27年  3階建    1階  13.8万円      -  13.8万円  ...  3LDK   65.72m2
# 2    築27年  3階建    1階  13.8万円      -  13.8万円  ...  3LDK   65.72m2
# 3     築3年  3階建    2階    18万円  5000円       -  ...  2LDK    56.5m2
# 4     築3年  3階建    2階    18万円  5000円       -  ...  2LDK    56.5m2
# ..    ...  ...   ...     ...    ...     ...  ...   ...       ...
# 190   築2年  2階建  1-2階    42万円      -    42万円  ...  2LDK  104.83m2
# 191   築2年  2階建  1-2階    42万円      -    42万円  ...  2LDK  104.83m2
# 192     0  3階建    2階   9.1万円  5000円   9.1万円  ...    1K   23.36m2
# 193     0  3階建    2階   9.5万円  5000円   9.5万円  ...    1K   24.81m2
# 194     0  3階建    1階    10万円  5000円    10万円  ...    1K   27.98m2
#
#                                                    URL   徒歩分   徒歩 walk  家賃金額  \
# 0    https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩11分  歩11   11  13.8
# 1    https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩20分  歩20   20  13.8
# 2    https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩23分  歩23   23  13.8
# 3    https://suumo.jp/chintai/jnc_000076182006/?bc=...   歩6分   歩6    6    18
# 4    https://suumo.jp/chintai/jnc_000076182006/?bc=...  歩12分  歩12   12    18
# ..                                                 ...   ...  ...  ...   ...
# 190  https://suumo.jp/chintai/jnc_000077201317/?bc=...  歩10分  歩10   10    42
# 191  https://suumo.jp/chintai/jnc_000077201317/?bc=...  歩16分  歩16   16    42
# 192  https://suumo.jp/chintai/jnc_000076446133/?bc=...   歩7分   歩7    7   9.1
# 193  https://suumo.jp/chintai/jnc_000076446134/?bc=...   歩7分   歩7    7   9.5
# 194  https://suumo.jp/chintai/jnc_000076446130/?bc=...   歩7分   歩7    7    10
#
#         平米数  築年数test 築年数数字
# 0     65.72      築27    27
# 1     65.72      築27    27
# 2     65.72      築27    27
# 3     56.50       築3     3
# 4     56.50       築3     3
# ..      ...      ...   ...
# 190  104.83       築2     2
# 191  104.83       築2     2
# 192   23.36        0
# 193   24.81        0
# 194   27.98        0
#
# [195 rows x 21 columns]

# %%
data_updated2["築年数数字"] = data_updated2["築年数数字"].astype('int')
data_updated2["家賃金額"] = data_updated2["家賃金額"].astype('float')
###data['walk'] = data['walk'].astype('int')

# %%
print(data_updated2.dtypes)

##数字型への変換終了
# Out:
# 名称          object
# カテゴリー       object
# アドレス        object
# アクセス        object
# 築年数         object
# 構造          object
# 階数          object
# 家賃          object
# 管理費         object
# 敷金          object
# 礼金          object
# 間取り         object
# 面積          object
# URL         object
# 徒歩分         object
# 徒歩          object
# walk         int64
# 家賃金額       float64
# 平米数        float64
# 築年数test     object
# 築年数数字        int64
# dtype: object

# %%
##data_updated2が分かりにくいので、変換
data_complete = data_updated2

# %%
data_complete.head()
# Out:
#           名称    カテゴリー         アドレス            アクセス   築年数   構造  階数      家賃  \
# 0  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/千歳烏山駅 歩11分  築27年  3階建  1階  13.8万円
# 1  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/芦花公園駅 歩20分  築27年  3階建  1階  13.8万円
# 2  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６    京王線/仙川駅 歩23分  築27年  3階建  1階  13.8万円
# 3   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４  小田急線/千歳船橋駅 歩6分   築3年  3階建  2階    18万円
# 4   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４   小田急線/経堂駅 歩12分   築3年  3階建  2階    18万円
#
#      管理費      敷金  ...   間取り       面積  \
# 0      -  13.8万円  ...  3LDK  65.72m2
# 1      -  13.8万円  ...  3LDK  65.72m2
# 2      -  13.8万円  ...  3LDK  65.72m2
# 3  5000円       -  ...  2LDK   56.5m2
# 4  5000円       -  ...  2LDK   56.5m2
#
#                                                  URL   徒歩分   徒歩 walk  家賃金額  \
# 0  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩11分  歩11   11  13.8
# 1  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩20分  歩20   20  13.8
# 2  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩23分  歩23   23  13.8
# 3  https://suumo.jp/chintai/jnc_000076182006/?bc=...   歩6分   歩6    6  18.0
# 4  https://suumo.jp/chintai/jnc_000076182006/?bc=...  歩12分  歩12   12  18.0
#
#      平米数  築年数test 築年数数字
# 0  65.72      築27    27
# 1  65.72      築27    27
# 2  65.72      築27    27
# 3  56.50       築3     3
# 4  56.50       築3     3
#
# [5 rows x 21 columns]

# %%
print(data_complete.dtypes)
# Out:
# 名称          object
# カテゴリー       object
# アドレス        object
# アクセス        object
# 築年数         object
# 構造          object
# 階数          object
# 家賃          object
# 管理費         object
# 敷金          object
# 礼金          object
# 間取り         object
# 面積          object
# URL         object
# 徒歩分         object
# 徒歩          object
# walk         int64
# 家賃金額       float64
# 平米数        float64
# 築年数test     object
# 築年数数字        int64
# dtype: object

# %%
##相関関係　： 築年数&家賃
plt.scatter(data_complete["家賃金額"], data_complete["築年数数字"])

# %%
res3=data_complete["家賃金額"].corr(data_complete["築年数数字"]) 
res3
# Out:
# 0.4968061961214318

# %%
##相関関係　： 徒歩&家賃
plt.scatter(data_complete["家賃金額"], data_complete["walk"])

# %%
res=data_complete["家賃金額"].corr(data_complete["walk"]) 
res
# Out:
# 0.11247503405438616

# %%
##相関関係　： 平米数&家賃
plt.scatter(data_complete["家賃金額"], data_complete["平米数"])

# %%
res2=data_complete["家賃金額"].corr(data_complete["平米数"]) 
res2
# Out:
# 0.9247865771188769

# %%
plt.hist(data_complete["家賃金額"])
# Out:
# (array([64452., 33012.,  6288.,  7860.,  7860., 14148.,  1572.,     0.,
#          1572.,  7860.]),
#  array([ 9.1 , 12.39, 15.68, 18.97, 22.26, 25.55, 28.84, 32.13, 35.42,
#         38.71, 42.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data_complete["平米数"])
# Out:
# (array([51876., 29868., 17292., 18864., 11004.,  4716.,  3144.,     0.,
#          1572.,  6288.]),
#  array([ 21.01 ,  31.338,  41.666,  51.994,  62.322,  72.65 ,  82.978,
#          93.306, 103.634, 113.962, 124.29 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data_complete["walk"])
# Out:
# (array([ 3144.,  8384., 41920., 12576., 37204.,  9956., 16768.,  6812.,
#          5764.,  2096.]),
#  array([ 2. ,  4.5,  7. ,  9.5, 12. , 14.5, 17. , 19.5, 22. , 24.5, 27. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data_complete["築年数数字"])
# Out:
# (array([58164., 12576., 11004., 25152., 18864.,     0.,  1572.,  9432.,
#          1572.,  6288.]),
#  array([ 0. ,  3.3,  6.6,  9.9, 13.2, 16.5, 19.8, 23.1, 26.4, 29.7, 33. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 分析について

# %%
#手順
#1: 分析のロジック策定（重回帰？）
#2インタラクティブアプリの作成（ユーザーが自分の情報を入力し、予測してくれる＋散布図の中でプロット）

# %%
#1重回帰分析
df = data_complete
df.head()
# Out:
#           名称    カテゴリー         アドレス            アクセス   築年数   構造  階数      家賃  \
# 0  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/千歳烏山駅 歩11分  築27年  3階建  1階  13.8万円
# 1  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/芦花公園駅 歩20分  築27年  3階建  1階  13.8万円
# 2  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６    京王線/仙川駅 歩23分  築27年  3階建  1階  13.8万円
# 3   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４  小田急線/千歳船橋駅 歩6分   築3年  3階建  2階    18万円
# 4   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４   小田急線/経堂駅 歩12分   築3年  3階建  2階    18万円
#
#      管理費      敷金  ...   間取り       面積  \
# 0      -  13.8万円  ...  3LDK  65.72m2
# 1      -  13.8万円  ...  3LDK  65.72m2
# 2      -  13.8万円  ...  3LDK  65.72m2
# 3  5000円       -  ...  2LDK   56.5m2
# 4  5000円       -  ...  2LDK   56.5m2
#
#                                                  URL   徒歩分   徒歩 walk  家賃金額  \
# 0  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩11分  歩11   11  13.8
# 1  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩20分  歩20   20  13.8
# 2  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩23分  歩23   23  13.8
# 3  https://suumo.jp/chintai/jnc_000076182006/?bc=...   歩6分   歩6    6  18.0
# 4  https://suumo.jp/chintai/jnc_000076182006/?bc=...  歩12分  歩12   12  18.0
#
#      平米数  築年数test 築年数数字
# 0  65.72      築27    27
# 1  65.72      築27    27
# 2  65.72      築27    27
# 3  56.50       築3     3
# 4  56.50       築3     3
#
# [5 rows x 21 columns]

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp310-cp310-macosx_10_9_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 9.3 MB/s eta 0:00:00:00:0100:01
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.3-cp310-cp310-macosx_10_9_x86_64.whl (34.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 7.6 MB/s eta 0:00:0000:0100:01m
# Collecting joblib>=1.0.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 4.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy>=1.17.3 in /Users/naokismacbookair/opt/anaconda3/envs/python10/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.23.4)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1304 sha256=991a9474518f11cff1c515b890ad9ce47274282e87d974dab7e8e70d5b0b5667
#   Stored in directory: /Users/naokismacbookair/Library/Caches/pip/wheels/9b/13/01/6f3a7fd641f90e1f6c8c7cded057f3394f451f340371c68f3d
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.2.0 scikit-learn-1.1.2 scipy-1.9.3 sklearn-0.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
#テストデータと学習データを作成
df.to_excel("all-data.xlsx")

# %%
#手動分割（Pythonでの実装を検討すべき）
train = pd.read_excel("train-suumo.xlsx")
test = pd.read_excel("test-suumo.xlsx")

train.head()
# Out:
#    Unnamed: 0         名称    カテゴリー         アドレス            アクセス   築年数   構造  階数  \
# 0           0  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/千歳烏山駅 歩11分  築27年  3階建  1階
# 1           1  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６  京王線/芦花公園駅 歩20分  築27年  3階建  1階
# 2           2  シンセリティ北烏山  賃貸マンション  東京都世田谷区北烏山６    京王線/仙川駅 歩23分  築27年  3階建  1階
# 3           3   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４  小田急線/千歳船橋駅 歩6分   築3年  3階建  2階
# 4           4   サントーレア経堂   賃貸アパート   東京都世田谷区経堂４   小田急線/経堂駅 歩12分   築3年  3階建  2階
#
#        家賃    管理費  ...   間取り       面積  \
# 0  13.8万円      -  ...  3LDK  65.72m2
# 1  13.8万円      -  ...  3LDK  65.72m2
# 2  13.8万円      -  ...  3LDK  65.72m2
# 3    18万円  5000円  ...  2LDK   56.5m2
# 4    18万円  5000円  ...  2LDK   56.5m2
#
#                                                  URL   徒歩分   徒歩 walk  家賃金額  \
# 0  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩11分  歩11   11  13.8
# 1  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩20分  歩20   20  13.8
# 2  https://suumo.jp/chintai/jnc_000077135145/?bc=...  歩23分  歩23   23  13.8
# 3  https://suumo.jp/chintai/jnc_000076182006/?bc=...   歩6分   歩6    6  18.0
# 4  https://suumo.jp/chintai/jnc_000076182006/?bc=...  歩12分  歩12   12  18.0
#
#      平米数  築年数test  築年数数字
# 0  65.72      築27     27
# 1  65.72      築27     27
# 2  65.72      築27     27
# 3  56.50       築3      3
# 4  56.50       築3      3
#
# [5 rows x 22 columns]

# %%
#データの正規化
from sklearn import preprocessing
mm = preprocessing.MinMaxScaler()

# %%
train_test = train[["築年数数字", "平米数", "walk"]]
train_test
# Out:
#         築年数数字    平米数  walk
# 0          27  65.72    11
# 1          27  65.72    20
# 2          27  65.72    23
# 3           3  56.50     6
# 4           3  56.50    12
# ...       ...    ...   ...
# 99996      14  26.31     9
# 99997      14  50.34     9
# 99998      14  53.13     9
# 99999      14  53.13     9
# 100000     14  53.13     9
#
# [100001 rows x 3 columns]

# %%
#正規化
train_nm = mm.fit_transform(train_test)
train_nm
# Out:
# array([[0.81818182, 0.43290085, 0.36      ],
#        [0.81818182, 0.43290085, 0.72      ],
#        [0.81818182, 0.43290085, 0.84      ],
#        ...,
#        [0.42424242, 0.31099923, 0.28      ],
#        [0.42424242, 0.31099923, 0.28      ],
#        [0.42424242, 0.31099923, 0.28      ]])

# %%
#正規化したものをDF化
df_train = pd.DataFrame(train_nm)
df_train
# Out:
#                0         1     2
# 0       0.818182  0.432901  0.36
# 1       0.818182  0.432901  0.72
# 2       0.818182  0.432901  0.84
# 3       0.090909  0.343629  0.16
# 4       0.090909  0.343629  0.40
# ...          ...       ...   ...
# 99996   0.424242  0.051317  0.28
# 99997   0.424242  0.283985  0.28
# 99998   0.424242  0.310999  0.28
# 99999   0.424242  0.310999  0.28
# 100000  0.424242  0.310999  0.28
#
# [100001 rows x 3 columns]

# %%
df_test = pd.DataFrame(index=['ONE', 'TWO', 'THREE'])
