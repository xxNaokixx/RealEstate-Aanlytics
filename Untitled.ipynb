# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
# %matplotlib inline

from sklearn.linear_model import LinearRegression as LR

from sklearn import preprocessing

import seaborn as sns
from sklearn.linear_model import LinearRegression



#データの前処理----------------------------------------------------
data = pd.read_excel("SUUMOスクレイピング.xlsx")

#データを分割
data["徒歩分"] = data["アクセス"].apply(lambda x : x.split(" ")[1])
data["徒歩"] = data["徒歩分"].apply(lambda x : x.split('分')[0])
data["walk"] = data["徒歩"].apply(lambda x : x.split('歩')[1])

data["walk"] = data["walk"].astype(np.int)

data["家賃金額"] = data["家賃"].apply(lambda x : x.split("万円")[0])

data["平米数"] = data["面積"].apply(lambda x : x.split("m2")[0])

data["築年数test"] = data["築年数"].apply(lambda x : x.split("年")[0])
data["築年数数字"] = data["築年数test"].apply(lambda x : x.split("築")[1])

data['walk'] = data['walk'].astype('int')
data["平米数"] = data["平米数"].astype('float')

replace = data["築年数数字"].replace("新築", 0)
data_updated = data.replace("新築", "0")
data_updated2 = data.replace("", "0")

data_updated2["築年数数字"] = data_updated2["築年数数字"].astype('int')
data_updated2["家賃金額"] = data_updated2["家賃金額"].astype('float')

data_complete = data_updated2

#データの前処理----------------------------------------------------
# Out:
# /var/folders/9j/g3nm72s54g5df75_4gzcrxth0000gn/T/ipykernel_48673/2745265720.py:23: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data["walk"] = data["walk"].astype(np.int)

# %%
#重回帰分析-------------------------------------------------------

df = data_complete

df.to_excel("all-data.xlsx")

train = pd.read_excel("train-suumo.xlsx")
test = pd.read_excel("test-suumo.xlsx")

mm = preprocessing.MinMaxScaler()

train_test = train[["築年数数字", "平米数", "walk"]]

train_nm = mm.fit_transform(train_test)

df_train = pd.DataFrame(train_nm)

df = df_train
df_train = df.rename(columns={0: "築年数数字", 1: "平米数", 2: "walk"})

test = test[["築年数数字", "平米数", "walk"]]

test_nm = mm.fit_transform(test)

df_test = pd.DataFrame(test_nm)

df2 = df_train
df_test = df2.rename(columns={0: "築年数数字", 1: "平米数", 2: "walk"})

model = LR()

target_data = pd.DataFrame(train["家賃金額"])
model.fit(target_data, df_train)

model.coef_

model.intercept_

model.score(target_data, df_train)

#重回帰分析-------------------------------------------------------
# Out:
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077257457/?bc=100286284928' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000062274318/?bc=100286373764' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077283885/?bc=100299843909' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075004792/?bc=100299127416' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000053251489/?bc=100292640994' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076102362/?bc=100292869911' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000047413149/?bc=100299843865' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000056552522/?bc=100292154720' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000047385642/?bc=100299843558' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077269819/?bc=100293951939' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075947598/?bc=100292197835' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000062945164/?bc=100280809499' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076450385/?bc=100297712378' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077072215/?bc=100298655406' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077121678/?bc=100299805696' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000074543509/?bc=100286394085' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076465229/?bc=100287819408' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075241078/?bc=100293423073' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076388913/?bc=100294722558' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077162761/?bc=100299071907' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077291146/?bc=100299909908' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000065694069/?bc=100285938245' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075096832/?bc=100286891341' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000066013712/?bc=100294568706' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000052419236/?bc=100299964962' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077201317/?bc=100299248175' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076446133/?bc=100295082064' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076446134/?bc=100295197797' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076446130/?bc=100295197803' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076446135/?bc=100295215491' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076446132/?bc=100295197706' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076446131/?bc=100295082057' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000040534437/?bc=100299984589' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000074276622/?bc=100298253815' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075207038/?bc=100287598146' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000074255605/?bc=100282797621' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000067361121/?bc=100223025750' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075792746/?bc=100291127052' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000064789168/?bc=100290513419' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075984661/?bc=100292178593' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000072510965/?bc=100279124760' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000072518782/?bc=100299946328' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000073399210/?bc=100282791027' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000073152398/?bc=100290513412' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000073399211/?bc=100287487731' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000066929202/?bc=100296186834' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075792747/?bc=100296143991' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000073560878/?bc=100287991624' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076640491/?bc=100296143981' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000072544660/?bc=100296186838' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000072510966/?bc=100299946447' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000073399212/?bc=100296144018' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000073172536/?bc=100289068856' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000073399213/?bc=100291042711' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077135145/?bc=100298888343' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076182006/?bc=100299926225' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077318529/?bc=100299897690' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077335210/?bc=100299927827' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077329665/?bc=100299929521' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076822657/?bc=100297032464' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076797801/?bc=100297033784' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076217858/?bc=100299235754' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076224044/?bc=100293600228' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000071480741/?bc=100298990873' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077276336/?bc=100299903772' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077335261/?bc=100299937986' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000072177963/?bc=100299029964' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077324035/?bc=100299890254' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077297949/?bc=100299941198' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077297981/?bc=100299826716' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077318541/?bc=100299832105' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000022759346/?bc=100299947266' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076701270/?bc=100299897618' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000077324046/?bc=100299832099' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000059823426/?bc=100299939759' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000038034916/?bc=100295170019' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000059392424/?bc=100299963584' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075843950/?bc=100298539843' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076939551/?bc=100297845529' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000061603162/?bc=100299940497' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076601385/?bc=100295950404' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000074974783/?bc=100287895713' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000017362830/?bc=100293097627' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076124526/?bc=100294492480' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076124527/?bc=100293016206' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000072204232/?bc=100271398180' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075687318/?bc=100291588800' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000075854529/?bc=100291896832' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076124529/?bc=100293002558' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076304528/?bc=100294129743' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076441267/?bc=100292418533' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1179: UserWarning: Ignoring URL 'https://suumo.jp/chintai/jnc_000076124528/?bc=100293108553' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# 0.3714331065161646

# %%
#単回帰分析-------------------------------------------------------
x = target_data
y = df[1]

plt.plot(x, y, 'o')
plt.show()

model_lr = LinearRegression()

model_lr.fit(x, y)

plt.plot(x, y, 'o')
plt.plot(x, model_lr.predict(x), linestyle="solid")
plt.show()

print('モデル関数の回帰変数 w1: %.3f' %model_lr.coef_)
print('モデル関数の切片 w2: %.3f' %model_lr.intercept_)
print('y= %.3fx + %.3f' % (model_lr.coef_ , model_lr.intercept_))
print('決定係数 R^2： ', model_lr.score(x, y))


#単回帰分析-------------------------------------------------------
# Out:
# モデル関数の回帰変数 w1: 0.025
# モデル関数の切片 w2: -0.187
# y= 0.025x + -0.187
# 決定係数 R^2：  0.8550809181247158

# %%
#単回帰分析2 -------------------------------------------------------
dfdf = pd.DataFrame(train["家賃金額"])
dfdf2 = pd.DataFrame(train["平米数"])

x = dfdf2
y = dfdf

plt.plot(x, y, 'o')
plt.show()

model_lr = LinearRegression()

model_lr.fit(x, y)

plt.plot(x, y, 'o')
plt.plot(x, model_lr.predict(x), linestyle="solid")
plt.show()

print('モデル関数の回帰変数 w1: %.3f' %model_lr.coef_)
print('モデル関数の切片 w2: %.3f' %model_lr.intercept_)
print('y= %.3fx + %.3f' % (model_lr.coef_ , model_lr.intercept_))
print('決定係数 R^2： ', model_lr.score(x, y))


#単回帰分析-------------------------------------------------------

##予測

dfdf3 = pd.DataFrame(test["平米数"])
pred = model_lr.predict(dfdf3)
pred2 = pd.DataFrame(pred)
pred2
# Out:
# モデル関数の回帰変数 w1: 0.325
# モデル関数の切片 w2: 1.882
# y= 0.325x + 1.882
# 決定係数 R^2：  0.8550809181247158
#                0
# 0      19.171814
# 1      19.171814
# 2      20.880267
# 3      10.258568
# 4      10.258568
# ...          ...
# 44618  10.701139
# 44619  10.704393
# 44620  10.701139
# 44621  10.704393
# 44622  12.354271
#
# [44623 rows x 1 columns]

# %%
##インプットから推論

user_input_m2 = int(input("平米数を書いてね"))


user_input_m22 = pd.DataFrame(
                 {'列名1':[user_input_m2]},
                 index = ['１']
                  )

input_pred = model_lr.predict(user_input_m22)
input_pred2 = pd.DataFrame(input_pred)
input_pred2
# Out:
# 平米数を書いてね20
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 列名1
# Feature names seen at fit time, yet now missing:
# - 平米数
#
#   warnings.warn(message, FutureWarning)
#           0
# 0  8.390659

# %%
user_input_m22
# Out:
#    列名1
# １   20

# %%
test["平米数"]
# Out:
# 0        53.13
# 1        53.13
# 2        58.38
# 3        25.74
# 4        25.74
#          ...
# 44618    27.10
# 44619    27.11
# 44620    27.10
# 44621    27.11
# 44622    32.18
# Name: 平米数, Length: 44623, dtype: float64

# %%
#予測
dfdf3 = pd.DataFrame(test["平米数"])
dfdf3

pred = model_lr.predict(dfdf3)

pred
# Out:
# array([[19.17181374],
#        [19.17181374],
#        [20.88026713],
#        ...,
#        [10.70113912],
#        [10.70439331],
#        [12.35427116]])

# %%
train["家賃金額"]
dfdf = pd.DataFrame(train["家賃金額"])
dfdf
# Out:
#         家賃金額
# 0       13.8
# 1       13.8
# 2       13.8
# 3       18.0
# 4       18.0
# ...      ...
# 99996   10.7
# 99997   21.2
# 99998   25.0
# 99999   26.0
# 100000  26.0
#
# [100001 rows x 1 columns]

# %%
train["平米数"]
dfdf2 = pd.DataFrame(train["平米数"])
dfdf2
# Out:
#           平米数
# 0       65.72
# 1       65.72
# 2       65.72
# 3       56.50
# 4       56.50
# ...       ...
# 99996   26.31
# 99997   50.34
# 99998   53.13
# 99999   53.13
# 100000  53.13
#
# [100001 rows x 1 columns]

# %%
dfdf = pd.DataFrame(test["平米数"])
dfdf
# Out:
#          平米数
# 0      53.13
# 1      53.13
# 2      58.38
# 3      25.74
# 4      25.74
# ...      ...
# 44618  27.10
# 44619  27.11
# 44620  27.10
# 44621  27.11
# 44622  32.18
#
# [44623 rows x 1 columns]

# %%
#yを正規化し直し
mm2 = preprocessing.MinMaxScaler()

y = mm2.fit_transform(dfdf)
yy = pd.DataFrame(y)
yy
# Out:
#               0
# 0      0.310999
# 1      0.310999
# 2      0.361832
# 3      0.045798
# 4      0.045798
# ...         ...
# 44618  0.058966
# 44619  0.059063
# 44620  0.058966
# 44621  0.059063
# 44622  0.108153
#
# [44623 rows x 1 columns]

# %%
#予測

#予測用のデータ
testfortest = yy
testfortest2 = testfortest.values.reshape(-1,1)

pred = model_lr.predict(testfortest2)

pred
# Out:
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-0.17933501, -0.17933501, -0.17804174, ..., -0.18574718,
#        -0.18574472, -0.18449578])

# %%
kak = pd.DataFrame(pred)
kak
# Out:
#               0
# 0     -0.179335
# 1     -0.179335
# 2     -0.178042
# 3     -0.186082
# 4     -0.186082
# ...         ...
# 44618 -0.185747
# 44619 -0.185745
# 44620 -0.185747
# 44621 -0.185745
# 44622 -0.184496
#
# [44623 rows x 1 columns]

# %%
kakunin = mm2.inverse_transform(kak)

kakunin2 = pd.DataFrame(kakunin)
kakunin2
# Out:
#               0
# 0      2.488280
# 1      2.488280
# 2      2.621849
# 3      1.791430
# 4      1.791430
# ...         ...
# 44618  1.826031
# 44619  1.826286
# 44620  1.826031
# 44621  1.826286
# 44622  1.955275
#
# [44623 rows x 1 columns]

# %%
#ユーザーのインプットを受け取り、散布図で表示---------------------------

#後で確認
plt.scatter(data_complete["家賃金額"], data_complete["平米数"])

user_input_m2 = input("平米数を書いてね（数字だけでいいよ）：")
user_input_m2 = int(user_input_m2)

user_input_yachin = int(input("家賃を書いてね(数字だけでいいよ)："))
user_input_yachin = int(user_input_yachin)

new_input_data = pd.DataFrame(
    data={'家賃金額': user_input_yachin, 
          '平米数': user_input_m2},
    index=[0]
)

origin_data = data_complete[["家賃金額", "平米数"]]
merged_data= origin_data.append(new_input_data)

#散布図の作成

plt.title('家賃と平米数の相関図',
                      fontsize=20) # タイトル
plt.xlabel("平米数（m2）", fontsize=20) # x軸ラベル
plt.ylabel("家賃（万円）", fontsize=20) # y軸ラベル
plt.grid(True) # 目盛線の表示
plt.tick_params(labelsize = 12) # 目盛線のラベルサイズ

plt.scatter(merged_data["家賃金額"], merged_data["平米数"], c="b", label="世の中の平均")

#散布図の関数化
plot_data = plt.scatter(merged_data["家賃金額"], merged_data["平米数"], c="b", label="世の中の平均")

plt.scatter(merged_data["家賃金額"], merged_data["平米数"], c="b", label="世の中の平均")
plt.scatter(user_input_yachin, user_input_m2, c="r", label="あなたのデータ") 


#ユーザーのインプットを受け取り、散布図で表示---------------------------
# Out:
# 平米数を書いてね（数字だけでいいよ）：20
# 家賃を書いてね(数字だけでいいよ)：20
# /var/folders/9j/g3nm72s54g5df75_4gzcrxth0000gn/T/ipykernel_48673/2831136198.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data= origin_data.append(new_input_data)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 23478 (\N{CJK UNIFIED IDEOGRAPH-5BB6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36035 (\N{CJK UNIFIED IDEOGRAPH-8CC3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31859 (\N{CJK UNIFIED IDEOGRAPH-7C73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38306 (\N{CJK UNIFIED IDEOGRAPH-95A2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22259 (\N{CJK UNIFIED IDEOGRAPH-56F3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 19975 (\N{CJK UNIFIED IDEOGRAPH-4E07}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/naokismacbookair/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20870 (\N{CJK UNIFIED IDEOGRAPH-5186}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
